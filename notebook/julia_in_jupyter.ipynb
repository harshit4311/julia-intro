# %%
println("hi")
# Out:
# hi

# %%
using Statistics, Distributions, Plots

# %%
data = rand(Normal(100, 15), 1000)
mean(data), std(data)
# Out:
# (100.14260621184663, 14.913955083617893)

# %%
histogram(data, bins=30, title="Histogram", xlabel="Value", ylabel="Count")
